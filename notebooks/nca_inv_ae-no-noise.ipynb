# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init

from tqdm.auto import tqdm

# %%
# torch.rand(10, 12, 32, 15).transpose(1, 3).shape

# %%
# SRC: https://github.com/chenmingxiang110/Growing-Neural-Cellular-Automata/blob/master/lib/CAModel.py
class CAModel(nn.Module):
    def __init__(self, channel_n, fire_rate, device, hidden_size=128):
        super(CAModel, self).__init__()

        self.device = device
        self.channel_n = channel_n

        self.fc0 = nn.Linear(channel_n * 3, hidden_size)
        self.fc1 = nn.Linear(hidden_size, channel_n, bias=False)
        init.zeros_(self.fc1.weight)

        self.fire_rate = fire_rate
        self.to(self.device)

    def alive(self, x):
        return F.max_pool2d(x[:, 3:4, :, :], kernel_size=3, stride=1, padding=1) > 0.1

    def perceive(self, x, angle):

        def _perceive_with(x, weight):
            conv_weights = torch.from_numpy(weight.astype(np.float32)).to(self.device)
            conv_weights = conv_weights.view(1, 1, 3, 3).repeat(self.channel_n, 1, 1, 1)
            return F.conv2d(x, conv_weights, padding=1, groups=self.channel_n)

        dx = np.outer([1, 2, 1], [-1, 0, 1]) / 8.0  # Sobel filter
        dy = dx.T
        c = np.cos(angle * np.pi / 180)
        s = np.sin(angle * np.pi / 180)
        w1 = c * dx - s * dy
        w2 = s * dx + c * dy

        y1 = _perceive_with(x, w1)
        y2 = _perceive_with(x, w2)
        y = torch.cat((x, y1, y2), 1)
        return y

    def update(self, x, fire_rate, angle):
        x = x.transpose(1, 3)
        pre_life_mask = self.alive(x)

        dx = self.perceive(x, angle)
        dx = dx.transpose(1, 3)
        dx = self.fc0(dx)
        dx = F.relu(dx)
        dx = self.fc1(dx)

        if fire_rate is None:
            fire_rate = self.fire_rate
        stochastic = torch.rand([dx.size(0), dx.size(1), dx.size(2), 1]) > fire_rate
        stochastic = stochastic.float().to(self.device)
        dx = dx * stochastic

        x = x + dx.transpose(1, 3)

        post_life_mask = self.alive(x)
        life_mask = (pre_life_mask & post_life_mask).float()
        x = x * life_mask
        return x.transpose(1, 3)

    def forward(self, x, steps=1, fire_rate=None, angle=0.0):
        x = x.transpose(1, 3)
        seq = [x.transpose(1, 3)]
        for step in range(steps):
            x = self.update(x, fire_rate, angle)
            seq.append(x.transpose(1, 3))
        return seq

# %%
class Decoder(nn.Module):
    def __init__(self, hid, seed_size):
        super().__init__()
        # self.net = nn.Sequential(
        #     nn.Flatten(),
        #     nn.Linear(SIZE * SIZE, 64),
        #     nn.BatchNorm1d(64),
        #     nn.ReLU(),
        #     nn.Linear(64, 64),
        #     nn.BatchNorm1d(64),
        #     nn.ReLU(),
        #     nn.Linear(64, 64),
        #     nn.BatchNorm1d(64),
        #     nn.ReLU(),
        #     nn.Linear(64, seed_size),
        # )
        self.net = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, padding=0, stride=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 16, kernel_size=3, padding=0, stride=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 16, kernel_size=5, padding=0, stride=2),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 16, kernel_size=5, padding=0, stride=2),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(256, seed_size)
        )

    def forward(self, x):
        return self.net(x)

# %%
CHANS = 16
FIRE_RATE = 0.5
device = "cuda"
HIDDEN_SIZE = 128
DECODER_HID = 128
BS = 32
SIZE = 32 # W,H
LR = 0.001

# %%
im = torch.rand(32, 1, 32, 32).to(device)
decoder = Decoder(DECODER_HID, CHANS).to(device)
res = decoder(im)
res.shape
# Out:
# torch.Size([32, 16])

# %%
model = CAModel(CHANS, FIRE_RATE, device=device, hidden_size=HIDDEN_SIZE)
decoder = Decoder(DECODER_HID, CHANS).to(device)

# Sanity check
inp = torch.rand(BS, CHANS, SIZE, SIZE).to(device)
seq = model(inp, steps=15)
last_frame = seq[-1]
last_frame_slice = last_frame[:, :1]
last_frame_slice.shape
decoded_hid = decoder(last_frame_slice)
decoded_hid.shape
# Out:
# torch.Size([32, 16])

# %%
# !pip install kornia

# !command -v ffmpeg >/dev/null || (apt update && apt install -y ffmpeg)
# !pip install -q mediapy

import kornia
import mediapy as media

# %%
noise = nn.Sequential(
    # kornia.augmentation.RandomAffine(
    #     degrees=10,
    #     translate=[0.1, 0.1],
    #     scale=[0.9, 1.5],
    #     shear=[-5, 5],
    #     p=0.9
    # ),
    # kornia.augmentation.RandomGaussianNoise(0, 1, p=0.5),
    # kornia.augmentation.RandomPerspective(0.6, p=0.5),
      kornia.augmentation.RandomAffine(
        degrees=5,
        translate=[0.01, 0.01],
        scale=[0.9, 1.1],
        shear=[-2, 2],
        p=0.9,
      ),
      kornia.augmentation.RandomErasing(scale=(0.05, 0.1), ratio=(0.5, 2), value=0.0, same_on_batch=False, p=0.9, keepdim=False),
      kornia.augmentation.RandomErasing(scale=(0.05, 0.1), ratio=(0.5, 2), value=0.0, same_on_batch=False, p=0.9, keepdim=False),
    #   kornia.augmentation.RandomPerspective(
    #     distortion_scale=0.5,
    #     p=0.5,
    #   ),
).to(device)

# %%
screen = torch.rand(10, 16, 32, 32)
noised_screen = noise(screen)
noised_screen.shape
# Out:
# torch.Size([10, 16, 32, 32])

# %%
normal_noise = torch.randn_like(noised_screen) / 30
media.show_images((noised_screen + normal_noise)[:, 0], border=True, height=150, cmap="viridis")
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %%
def generate_inputs(bs, chans, size):
    while True:
        screen = torch.zeros(bs, chans, size, size)
        seeds = torch.randn(bs, chans)
        screen[:, :, size//2, size//2] = seeds

        yield screen, seeds

# %%
input_gen = generate_inputs(BS, CHANS, SIZE)
batch = next(input_gen)
screen, seeds = batch
screen.shape, seeds.shape
# Out:
# (torch.Size([32, 16, 32, 32]), torch.Size([32, 16]))

# %%
# media.show_images(screen[:, 0], border=True, height=150, cmap="viridis")

# %%
batch = next(input_gen)
screen, seeds = batch
screen, seeds = screen.to(device), seeds.to(device)

seq = model(screen, steps=15)
last_frame = seq[-1]
last_frame_slide = last_frame[:, :1]
noised_last_frame = noise(last_frame_slide)

decoded = decoder(noised_last_frame)
decoded.shape, seeds.shape
# Out:
# (torch.Size([32, 16]), torch.Size([32, 16]))

# %%
model = CAModel(CHANS, FIRE_RATE, device=device, hidden_size=HIDDEN_SIZE)
decoder = Decoder(DECODER_HID, CHANS).to(device)
input_gen = generate_inputs(BS, CHANS, SIZE)
history = []

# %%
import matplotlib.pyplot as plt
from IPython.display import display, clear_output

def to_numpy(t):
    return t.detach().cpu().numpy()

# %%
optim = torch.optim.Adam([*model.parameters(), *decoder.parameters()], lr=LR)
pbar = tqdm(range(100000))

for i in pbar:
    batch = next(input_gen)
    screen, seeds = batch

    S = np.random.randint(4, 100)

    seq = model(screen.to(device), steps=S // 2)
    last_frame = seq[-1]
    decoded = decoder(last_frame[:, :1])

    optim.zero_grad()
    loss = F.mse_loss(decoded, seeds.to(device))
    loss.backward()
    optim.step()
    history.append(loss.item())

    pbar.set_description(f"Loss: {loss.item():0.5f}")
    if i % 250 == 0:
        clear_output()

        display(pbar.container)

        plt.plot(history)
        plt.yscale("log")
        plt.show()

        media.show_images(to_numpy(seq[-1][:10])[:, 0], border=True, height=100, cmap="viridis", columns=10)
        
        input_gen_small = generate_inputs(5, CHANS, SIZE)
        batch = next(input_gen_small)
        screen, seeds = batch
        seq = model(screen.to(device), steps=100)
        media.show_videos(
            media.to_rgb(to_numpy(torch.stack(seq).transpose(0, 1)[:,:,0]), vmin=0, vmax=1, cmap="viridis"),
            height=150, fps=20, codec='gif', border=True, columns=16
        )
# Out:
# Loss: 0.54813:  67%|######7   | 67249/100000 [1:09:10<39:21, 13.87it/s]
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td></tr></table>
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td></tr></table>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 18
#      16 loss.backward()
#      17 optim.step()
# ---> 18 history.append(loss.item())
#      20 pbar.set_description(f"Loss: {loss.item():0.5f}")
#      21 if i % 250 == 0:
#
# KeyboardInterrupt:

# %%
from datetime import datetime
import os

now = datetime.now()
save_dir = "./saved"
os.makedirs(save_dir, exist_ok=True)

nca_path = os.path.join(save_dir, f"nca_no_noise_{now}.pkl")
decoder_path = os.path.join(save_dir, f"decoder_no_noise_{now}.pkl")

with open(nca_path, "wb+") as fp:
    torch.save(model, fp)
with open(decoder_path, "wb+") as fp:
    torch.save(decoder, fp)

# %%
batch = next(input_gen)
screen, seeds = batch

S = np.random.randint(4, 50)

seq = model(screen.to(device), steps=100)

# %%
media.show_videos(
    to_numpy(torch.stack(seq).transpose(0, 1)[:,:,0]),
    height=100, fps=8, codec='gif', border=True, columns=16
)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td></tr></table><table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover ...

# %%
input_gen_small = generate_inputs(5, CHANS, SIZE)
batch = next(input_gen_small)
screen, seeds = batch

S = 100

seq = model(screen.to(device), steps=S)
media.show_videos(
    media.to_rgb(to_numpy(torch.stack(seq).transpose(0, 1)[:,:,0]), vmin=0, vmax=1, cmap="viridis"),
    height=150, fps=20, codec='gif', border=True, columns=16
)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td></tr></table>

# %%
batch = next(input_gen)
screen, seeds = batch

S = 50

seq = model(screen.to(device), steps=S // 2)
last_frame = seq[-1]
noised_last_frame = noise(last_frame)
normal_noise = torch.randn_like(noised_last_frame) / 30
# noised_last_frame += normal_noise

seq2 = model(noised_last_frame, steps=S // 2)

# %%
media.show_videos(
    media.to_rgb(to_numpy(torch.stack(seq + seq2).transpose(0, 1)[:,:,0]), vmin=0, vmax=1, cmap="viridis"),
    height=100, fps=20, codec='gif', border=True, columns=16
)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td></tr></table><table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover ...

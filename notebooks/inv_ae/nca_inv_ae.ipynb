# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
import wandb
import os

from tqdm.auto import tqdm

# !pip install kornia
# !command -v ffmpeg >/dev/null || (apt update && apt install -y ffmpeg)
# !pip install -q mediapy
import kornia
import mediapy as media

# %%
# torch.set_default_dtype(torch.float16)

# %%
os.environ["WANDB_NOTEBOOK_NAME"] = "./nca_inv_ae.ipynb"

# %%
import matplotlib.pyplot as plt
from IPython.display import display, clear_output

def to_numpy(t):
    return t.detach().cpu().numpy()

# %%
# SRC: https://github.com/chenmingxiang110/Growing-Neural-Cellular-Automata/blob/master/lib/CAModel.py
class CAModel(nn.Module):
    def __init__(self, channel_n, fire_rate, device, hidden_size=128):
        super(CAModel, self).__init__()

        self.device = device
        self.channel_n = channel_n

        self.fc0 = nn.Linear(channel_n * 3, hidden_size)
        self.fc1 = nn.Linear(hidden_size, channel_n, bias=False)
        init.zeros_(self.fc1.weight)

        self.fire_rate = fire_rate
        self.to(self.device)

    def alive(self, x):
        return F.max_pool2d(x[:, :1, :, :], kernel_size=3, stride=1, padding=0) > 0.1

    def perceive(self, x, angle):
        def _perceive_with(x, weight):
            conv_weights = torch.from_numpy(weight.astype(np.float32)).to(self.device)
            conv_weights = conv_weights.view(1, 1, 3, 3).repeat(self.channel_n, 1, 1, 1)
            return F.conv2d(x, conv_weights, padding=0, groups=self.channel_n)

        dx = np.outer([1, 2, 1], [-1, 0, 1]) / 8.0  # Sobel filter
        dy = dx.T
        c = np.cos(angle * np.pi / 180)
        s = np.sin(angle * np.pi / 180)
        w1 = c * dx - s * dy
        w2 = s * dx + c * dy

        y1 = _perceive_with(x, w1)
        y2 = _perceive_with(x, w2)
        return y1, y2

    def update(self, x, fire_rate, angle):
        x_padded = F.pad(x, (1, 1, 1, 1), "circular")
        pre_life_mask = self.alive(x_padded)
        y1, y2 = self.perceive(x_padded, angle)
        dx = torch.cat([x, y1, y2], dim=1)

        dx = dx.permute(0, 2, 3, 1)
        dx = self.fc0(dx)
        dx = F.relu(dx)
        dx = self.fc1(dx)
        dx = dx.permute(0, 3, 1, 2)

        if fire_rate is None:
            fire_rate = self.fire_rate
        stochastic = torch.rand([dx.size(0), dx.size(1), dx.size(2), 1]) > fire_rate
        stochastic = stochastic.float().to(self.device)
        dx = dx * stochastic

        x = x + dx

        post_life_mask = self.alive(F.pad(x, (1, 1, 1, 1), "circular"))
        life_mask = (pre_life_mask & post_life_mask).float()
        x = x * life_mask
        return x

    def forward(self, x, steps=1, fire_rate=None, angle=0.0):
        seq = [x]
        for step in range(steps):
            x = self.update(x, fire_rate, angle)
            seq.append(x)
        return seq

# %%
class Decoder(nn.Module):
    def __init__(self, hid, seed_size):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=0, stride=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 32, kernel_size=3, padding=0, stride=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 32, kernel_size=5, padding=0, stride=2),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32,16, kernel_size=5, padding=0, stride=2),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(256, seed_size),
        )

    def forward(self, x):
        return self.net(x)

# %%
CHANS = 32
FIRE_RATE = 0.0
device = "cuda"
HIDDEN_SIZE = 128
DECODER_HID = 128
BS = 32
SIZE = 32 # W,H
LR = 0.001

# %%
im = torch.rand(32, 1, 32, 32).to(device)
decoder = Decoder(DECODER_HID, CHANS).to(device)
res = decoder(im)
res.shape
# Out:
# torch.Size([32, 32])

# %%
def plot_seq_stat(seq):
    m = to_numpy(torch.stack(seq).transpose(0, 1))
    b,s,c,h,w = m.shape
    merged = m.reshape(b,s,c*h*w)
    ma = abs(merged).max(axis=-1)
    s = abs(merged).sum(axis=-1)
    m = merged.max(axis=-1)
    
    fig, axs = plt.subplots(1, 2, figsize=(8, 2))
    axs[0].set_title("sum")
    axs[1].set_title("max")
    for x in s:
        axs[0].plot(x, c="tab:blue", alpha=0.2)
    for x in m:
        axs[1].plot(x, c="tab:red", alpha=0.2)
    plt.tight_layout()
    plt.show()

# %%
model = CAModel(CHANS, FIRE_RATE, device=device, hidden_size=HIDDEN_SIZE)
decoder = Decoder(DECODER_HID, CHANS).to(device)

# Sanity check
inp = torch.rand(BS, CHANS, SIZE, SIZE).to(device)
seq = model(inp, steps=15)
last_frame = seq[-1]
last_frame_slice = last_frame[:, :1]
last_frame_slice.shape
decoded_hid = decoder(last_frame_slice)
decoded_hid.shape
# Out:
# torch.Size([32, 32])

# %%
# plot_seq_stat(seq)

# %%
noise = nn.Sequential(
    kornia.augmentation.RandomAffine(
        degrees=20,
        translate=[0.0, 0.05],
        scale=[0.9, 1.1],
        shear=[-10, 10],
        p=1,
    ),
    kornia.augmentation.RandomErasing(
        scale=(0.01, 0.02), ratio=(0.5, 2),
        value=0, p=1,
    ),
    kornia.augmentation.RandomGaussianNoise(0, 0.1, p=1),
).to(device)

# %%
screen = torch.rand(10, 16, 32, 32)
noised_screen = noise(screen)
noised_screen.shape
# Out:
# torch.Size([10, 16, 32, 32])

# %%
media.show_images(noised_screen[:, 0], border=True, height=150, cmap="viridis")
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %%
def generate_inputs(bs, chans, size):
    while True:
        screen = torch.zeros(bs, chans, size, size)
        seeds = torch.rand(bs, chans)
        seeds[:, chans//2:] = 1
        seeds[:, 0] = 1
        for i in range(bs):
            screen[i, :, np.random.randint(0, size), np.random.randint(0, size)] = seeds[i]

        yield screen, seeds

# %%
input_gen = generate_inputs(BS, CHANS, SIZE)
batch = next(input_gen)
screen, seeds = batch
screen.shape, seeds.shape
# Out:
# (torch.Size([32, 32, 32, 32]), torch.Size([32, 32]))

# %%
batch = next(input_gen)
screen, seeds = batch
screen, seeds = screen.to(device), seeds.to(device)

seq = model(screen, steps=15)
last_frame = seq[-1]
last_frame_slide = last_frame[:, :1]
noised_last_frame = noise(last_frame_slide)

decoded = decoder(noised_last_frame)
decoded.shape, seeds.shape
# Out:
# (torch.Size([32, 32]), torch.Size([32, 32]))

# %%
model = CAModel(CHANS, FIRE_RATE, device=device, hidden_size=HIDDEN_SIZE)
decoder = Decoder(DECODER_HID, CHANS // 2).to(device)
input_gen = generate_inputs(BS, CHANS, SIZE)
history = []

# %%
run = wandb.init(
    project="nca-classifier",
    config={
        "learning_rate": LR,
    },
    save_code=True,
)
_ = run.log_code(
    "../",
    include_fn=lambda path: path.endswith(".py") or path.endswith(".ipynb"),
)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: ichko to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/home/iz/workspace/nca/inv_ae/wandb/run-20250417_202848-qli1onmy</code>
# Syncing run <strong><a href='https://wandb.ai/ichko/nca-classifier/runs/qli1onmy' target="_blank">jolly-shape-22</a></strong> to <a href='https://wandb.ai/ichko/nca-classifier' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ichko/nca-classifier' target="_blank">https://wandb.ai/ichko/nca-classifier</a>
#  View run at <a href='https://wandb.ai/ichko/nca-classifier/runs/qli1onmy' target="_blank">https://wandb.ai/ichko/nca-classifier/runs/qli1onmy</a>

# %%
optim = torch.optim.Adam([*model.parameters(), *decoder.parameters()], lr=LR)
pbar = tqdm(range(50_000))

for i in pbar:
    input_gen_small = generate_inputs(5, CHANS, SIZE)
    batch = next(input_gen)
    screen, seeds = batch

    S = np.random.randint(99, 100)

    seq = model(screen.to(device), steps=S)
    start_frame = seq[30][:,:1]
    mid_frame = seq[60][:,:1]
    last_frame = seq[-1][:,:1]


    optim.zero_grad()
    loss = 0
#     loss += F.mse_loss(decoder(noise(start_frame)), seeds[:, :CHANS//2].to(device))
#     loss += F.mse_loss(decoder(noise(mid_frame)), seeds[:, CHANS//2:].to(device))
    loss += F.mse_loss(decoder(noise(last_frame)), seeds[:, :CHANS//2].to(device))

    abs_frame = torch.abs(last_frame)
    peaks = abs_frame[abs_frame > 1.1] - 1.1
    if len(peaks) > 0:
        loss += peaks.mean() / 1000
    
    max_mass = 400
    mass = abs_frame.sum(axis=[1,2,3]).mean()
    if mass > max_mass:
        loss *= 2

    loss.backward()
    optim.step()
    history.append(loss.item())

    pbar.set_description(f"Loss: {loss.item():0.5f}")
    run.log({"loss": loss.item()})

    if i % 250 == 0:
        clear_output()

        display(pbar.container)

        plt.plot(history)
        plt.yscale("log")
        plt.show()

        media.show_images(
            to_numpy(seq[-1][:10])[:, 0], border=True, height=100, cmap="viridis", columns=10)
        media.show_images(
            to_numpy(noise(seq[-1][:10]))[:, 0], border=True, height=100, cmap="viridis", columns=10)
        
        input_gen_small = generate_inputs(5, CHANS, SIZE)
        batch = next(input_gen_small)
        screen, seeds = batch
        seq = model(screen.to(device), steps=100)
        media.show_videos(
            media.to_rgb(
                to_numpy(torch.stack(seq).transpose(0, 1)[:,:,0]),
                vmin=-1, vmax=1, cmap="viridis"
            ),
            height=150, fps=20, codec='gif', border=True, columns=16
        )
        plot_seq_stat(seq)
# Out:
# Loss: 0.07580:  18%|#8        | 9000/50000 [25:08<1:52:02,  6.10it/s]
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="..."/></td></tr></table>
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td></tr></table>
# KeyboardInterrupt
#
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7c873679c1f0>>
# Traceback (most recent call last):
#   File "/home/iz/.cache/pypoetry/virtualenvs/nca-ar8j7Liq-py3.10/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 790, in _clean_thread_parent_frames
#     active_threads = {thread.ident for thread in threading.enumerate()}
#   File "/home/iz/.cache/pypoetry/virtualenvs/nca-ar8j7Liq-py3.10/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 790, in <setcomp>
#     active_threads = {thread.ident for thread in threading.enumerate()}
# KeyboardInterrupt:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7c873679c1f0>>
# Traceback (most recent call last):
#   File "/home/iz/.cache/pypoetry/virtualenvs/nca-ar8j7Liq-py3.10/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# Error in callback <bound method _WandbInit._pause_backend of <wandb.sdk.wandb_init._WandbInit object at 0x7c86495832b0>> (for post_run_cell), with arguments args (<ExecutionResult object at 7c86465f9660, execution_count=20 error_before_exec=None error_in_exec= info=<ExecutionInfo object at 7c86465fb250, raw_cell="optim = torch.optim.Adam([*model.parameters(), *de.." store_history=True silent=False shell_futures=True cell_id=None> result=None>,),kwargs {}:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7c873679c1f0>>
# Traceback (most recent call last):
#   File "/home/iz/.cache/pypoetry/virtualenvs/nca-ar8j7Liq-py3.10/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
#
# KeyboardInterrupt

# %%
run.finish()

# %%
# del decoder

# %%
with torch.no_grad():
    plt.plot(history)
    plt.yscale("log")
    plt.show()

    media.show_images(to_numpy(seq[-1][:10])[:, 0], border=True, height=100, cmap="viridis", columns=10)

    input_gen_small = generate_inputs(5, CHANS, SIZE)
    batch = next(input_gen_small)
    screen, seeds = batch
    seq = model(screen.to(device), steps=500)
    media.show_videos(
        media.to_rgb(to_numpy(torch.stack(seq).transpose(0, 1)[:,:,0]), vmin=0, vmax=1, cmap="viridis"),
        height=150, fps=20, codec='gif', border=True, columns=16
    )
    plot_seq_stat(seq)

# %%
from datetime import datetime
import os

now = datetime.now()
save_dir = "./saved"
os.makedirs(save_dir, exist_ok=True)

nca_path = os.path.join(save_dir, f"nca_{now}.pkl")
decoder_path = os.path.join(save_dir, f"nca_{now}.pkl")

with open(nca_path) as fp:
    torch.save(mdoel, fp)
with open(decoder_path) as fp:
    torch.save(mdoel, fp)

# %%
batch = next(input_gen)
screen, seeds = batch

S = np.random.randint(4, 50)

seq = model(screen.to(device), steps=100)

# %%
media.show_videos(
    to_numpy(torch.stack(seq).transpose(0, 1)[:,:,0]),
    height=100, fps=8, codec='gif', border=True, columns=16
)

# %%
input_gen_small = generate_inputs(5, CHANS, SIZE)
batch = next(input_gen_small)
screen, seeds = batch

S = 100

seq = model(screen.to(device), steps=S)
media.show_videos(
    media.to_rgb(to_numpy(torch.stack(seq).transpose(0, 1)[:,:,0]), vmin=0, vmax=1, cmap="viridis"),
    height=150, fps=20, codec='gif', border=True, columns=16
)

# %%
batch = next(input_gen)
screen, seeds = batch

S = 50

seq = model(screen.to(device), steps=S // 2)
last_frame = seq[-1]
noised_last_frame = noise(last_frame)
normal_noise = torch.randn_like(noised_last_frame) / 30
# noised_last_frame += normal_noise

seq2 = model(noised_last_frame, steps=S // 2)

# %%
media.show_videos(
    media.to_rgb(to_numpy(torch.stack(seq + seq2).transpose(0, 1)[:,:,0]), vmin=0, vmax=1, cmap="viridis"),
    height=100, fps=20, codec='gif', border=True, columns=16
)
